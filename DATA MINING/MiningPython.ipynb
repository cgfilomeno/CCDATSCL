# %% [markdown]
# ### **Data Mining Using Python**

# %% [markdown]
# <font color="red">File access required:</font> In Colab this notebook requires first uploading files **Shop.csv** and **Movies.csv** using the *Files* feature in the left toolbar. If running the notebook on a local computer, simply ensure these files are in the same workspace as the notebook.

# %%
# Set-up
import csv

# %% [markdown]
# **Look at CSV files:** TID,item pairs

# %%
# Read shopping dataset from CSV file
# Create dictionary "Sitems" with key = item and value = set of transactions
# Also set variable Snumtrans = number of transactions
Sitems = {}
trans = []  # list of transactions used to set Snumtrans
with open('Shop.csv') as f:
    rows = csv.DictReader(f)
    for r in rows:
        if r['item'] not in Sitems:
            Sitems[r['item']] = {r['TID']}
        else:
            Sitems[r['item']].add(r['TID'])
        if r['TID'] not in trans:
            trans.append(r['TID'])
Snumtrans = len(trans)
print('Number of transactions:', Snumtrans)
print('Number of distinct items:', len(Sitems))
print('Item dictionary:')
Sitems
# Out:
# Number of transactions: 5
# Number of distinct items: 5
# Item dictionary:
# {'milk': {'1', '2', '4', '5'},
#  'eggs': {'1', '3', '4'},
#  'juice': {'1', '2', '5'},
#  'cookies': {'2', '5'},
#  'chips': {'3', '5'}}

# %%
# Read movies dataset from CSV file
# Create dictionary "Mitems" with key = item and value = set of transactions
# Also set variable Mnumtrans = number of transactions
Mitems = {}
trans = []  # list of transactions used to set Mnumtrans
with open('Movies.csv') as f:
    rows = csv.DictReader(f)
    for r in rows:
        if r['item'] not in Mitems:
            Mitems[r['item']] = {r['TID']}
        else:
            Mitems[r['item']].add(r['TID'])
        if r['TID'] not in trans:
            trans.append(r['TID'])
Mnumtrans = len(trans)
print('Number of transactions (users):', Mnumtrans)
print('Number of distinct items (movies):', len(Mitems))
print('Item dictionary:')
Mitems.items()
# Out:
# Number of transactions (users): 1382
# Number of distinct items (movies): 123
# Item dictionary:
# dict_items([('The Fault in Our Stars', {'243482', '36040', '214778', '102371', '39827', '166205', '232001', '58296', '145755', '62076', '4208', '114602', '96530', '6802', '105996', '18805', '233542', '206146', '215987', '69759', '69391', '121896', '186450', '191042', '152735', '134268', '111288', '34280', '105787', '218669', '184307', '41453', '3508', '204050', '240694', '221712', '173452', '127474', '46770', '12924', '102901', '229131', '140380', '7353', '72265', '176880', '71352', '78715', '43142', '158048', '71268', '31198', '234322', '98509', '158208', '218424', '150676', '28304', '89200', '115516', '210968', '50601', '152646', '15530', '54212', '171575', '144712', '120662', '55096', '47173', '241263', '6573', '206129', '92094', '29139', '14642', '38153', '171673', '100316', '87907', '61803', '87127', '174147', '4231', '15590', '168240', '54858', '101420', '151368', '239816', '56323', '22793', '68551', '176', '232320', '25851', '153533', '237123', '128828', '200931', '184040', '126898', '128203', '124830', '244116', '121408', '163775', '165260', '174077', '167831', '241916'}), ('Boyhood', {'3962', '243482', '36040', '15466', '132287', '7556', '39827', '216969', '222218', '51681', '71124', '14588', '147652', '13710', '232001', '233042', '17915', '148467', '150186', '126624', '39014', '145755', '62076', '63672', '3266', '196565', '116822', '4208', '48950', '228748', '167614', '176875', '94957', '232165', '99742', '18805', '77903', '139205', '206146', '215987', '40926', '230758', '99004', '76891', '204070', '208473', '111288', '90727', '34280', '244769', '176725', '14902', '202380', '218669', '105787', '184307', '214028', '123552', '3967', '196576', '106668', '247354', '240694', '221712', '127474', '75928', '143932', '156989', '52898', '75198', '70585', '39070', '49159', '9585', '24214', '34018', '7353', '138121', '220810', '34950', '98054', '87948', '75555', '207966', '241577', '72265', '216620', '89562', '90516', '27210', '15823', '204770', '72653', '140741', '151584', '27365', '98732', '26073', '213657', '73132', '35936', '43142', '72725', '95669', '71268', '73352', '117731', '141192', '158208', '145136', '126382', '201218', '14883', '197358', '77949', '150676', '66551', '228452', '220049', '94344', '209357', '139324', '150148', '229857', '153764', '199241', '115171', '27332', '213606', '106700', '68079', '56344', '34520', '159840', '17264', '177422', '50601', '68930', '208149', '162786', '94555', '128655', '116345', '50188', '133012', '99848', '179447', '200039', '144712', '5415', '122188', '102294', '9444', '146607', '47173', '160895', '105750', '246553', '170329', '90271', '241263', '6573', '206129', '92094', '29139', '79910', '38153', '40611', '99876', '194682', '100316', '182194', '87907', '44027', '233266', '115786', '12354', '4588', '4231', '96721', '15590', '241656', '168240', '74793', '125182', '55980', '101420', '246994', '71301', '179625', '74343', '57305', '182961', '238755', '68551', '46106', '6199', '15273', '176', '211373', '180951', '94774', '153533', '198726', '205045', '6592', '214091', '13399', '184040', '152679', '64144', '4987', '129638', '124830', '131820', '207834', '244116', '163775', '20316', '176934', '243657', '78095', '124349', '6569', '110968', '8215', '87122', '169154'}), ('Big Hero 6', {'243482', '173988', '181327', '42841', '226479', '10096', '14588', '94246', '7695', '6198', '62076', '75806', '17574', '116822', '1040', '24427', '128859', '54515', '206146', '84605', '118774', '106446', '230758', '208473', '126642', '211713', '244769', '16939', '41453', '22394', '227290', '173452', '175887', '162227', '36445', '61096', '201282', '158613', '145445', '27210', '716', '119108', '72653', '225664', '33895', '105122', '139364', '201218', '84555', '87222', '53303', '166692', '70985', '45835', '135513', '214792', '180177', '176170', '171452', '68079', '184893', '183219', '222806', '168533', '234011', '120662', '171801', '146607', '61726', '190201', '92094', '40611', '23766', '171673', '87907', '44027' ...

# %% [markdown]
# ### Some new Python features

# %%
# Iterating through dictionaries
for i in Sitems:
    print(i)
    print(Sitems[i])
# Out:
# milk
# {'5', '4', '2', '1'}
# eggs
# {'4', '3', '1'}
# juice
# {'5', '2', '1'}
# cookies
# {'2', '5'}
# chips
# {'3', '5'}

# %%
# Intersecting sets
# How many transactions contain both eggs and milk?
set1 = Sitems['eggs']
print('Transactions containing eggs:', set1)
set2 = Sitems['milk']
print('Transactions containing milk:', set2)
set3 = set1 & set2
print('Transactions containing both:', set3)
# print('Number of transactions containing both:', len(set3))
# Out:
# Transactions containing eggs: {'4', '3', '1'}
# Transactions containing milk: {'5', '4', '2', '1'}
# Transactions containing both: {'4', '1'}

# %% [markdown]
# ## Shopping dataset - frequent item-sets

# %% [markdown]
# ### Frequent item-sets of two

# %% [markdown]
# #### Print all pairs of items and the number of transactions they occur together in (see what's wrong and fix it)

# %%
for i1 in Sitems:
    for i2 in Sitems:
        common = len(Sitems[i1] & Sitems[i2])
        print([i1, i2, common])
# Out:
# ['milk', 'milk', 4]
# ['milk', 'eggs', 2]
# ['milk', 'juice', 3]
# ['milk', 'cookies', 2]
# ['milk', 'chips', 1]
# ['eggs', 'milk', 2]
# ['eggs', 'eggs', 3]
# ['eggs', 'juice', 1]
# ['eggs', 'cookies', 0]
# ['eggs', 'chips', 1]
# ['juice', 'milk', 3]
# ['juice', 'eggs', 1]
# ['juice', 'juice', 3]
# ['juice', 'cookies', 2]
# ['juice', 'chips', 1]
# ['cookies', 'milk', 2]
# ['cookies', 'eggs', 0]
# ['cookies', 'juice', 2]
# ['cookies', 'cookies', 2]
# ['cookies', 'chips', 1]
# ['chips', 'milk', 1]
# ['chips', 'eggs', 1]
# ['chips', 'juice', 1]
# ['chips', 'cookies', 1]
# ['chips', 'chips', 2]

# %% [markdown]
# #### Now only print pairs that meet support threshold

# %%
support = .3
for i1 in Sitems:
    for i2 in Sitems:
      if i1 < i2:
        common = len(Sitems[i1] & Sitems[i2])
        if common/Snumtrans > support:
          print(i1, '|', i2)
# Out:
# eggs | milk
# juice | milk
# cookies | milk
# cookies | juice

# %% [markdown]
# ### Frequent item-sets of three

# %%
support = .1
for i1 in Sitems:
    for i2 in Sitems:
        for i3 in Sitems:
            if i1 < i2 and i2 < i3:
                common = len(Sitems[i1] & Sitems[i2] & Sitems[i3])
                if common/Snumtrans > support:
                    print(i1, '|', i2, '|', i3)
# Out:
# eggs | juice | milk
# cookies | juice | milk
# chips | juice | milk
# chips | cookies | milk
# chips | cookies | juice

# %% [markdown]
# ### <font color = 'green'>**Your Turn - Movies dataset frequent item-sets**</font>

# %%
print(Mnumtrans, 'transactions (users)')
print(len(Mitems), 'distinct items (movies)')
# Out:
# 1382 transactions (users)
# 123 distinct items (movies)

# %% [markdown]
# #### Mine for frequent item-sets of three and four items in the Movies dataset. Find a single support threshold where the number of frequent item-sets of three items is more than 10 but less than 20, and the number of frequent item-sets of four items is more than 0.

# %%
# Frequent item-sets of three
support = 0.03
for i1 in Mitems:
    for i2 in Mitems:
        for i3 in Mitems:
            if i1 < i2 and i2 < i3:
                common = len(Mitems[i1] & Mitems[i2] & Mitems[i3])
                if common/Mnumtrans > support:
                    print(i1, '|', i2, '|', i3)
# Out:
# Boyhood | Inside Out | The Imitation Game
# Boyhood | Gone Girl | The Imitation Game
# Boyhood | Gone Girl | Inside Out
# Boyhood | Fury | The Imitation Game
# Boyhood | Fury | Gone Girl
# Big Hero 6 | Boyhood | The Imitation Game
# Big Hero 6 | Boyhood | Gone Girl
# Big Hero 6 | Inside Out | The Imitation Game
# Big Hero 6 | Gone Girl | The Imitation Game
# Big Hero 6 | Gone Girl | Inside Out
# Big Hero 6 | Fury | The Imitation Game
# Big Hero 6 | Fury | Gone Girl
# Gone Girl | Inside Out | The Imitation Game
# Fury | Gone Girl | The Imitation Game

# %%
# Frequent item-sets of four
support = 0.03
for i1 in Mitems:
    for i2 in Mitems:
        for i3 in Mitems:
            for i4 in Mitems:
              if i1 < i2 and i2 < i3 and i3 < i4:
                common = len(Mitems[i1] & Mitems[i2] & Mitems[i3] & Mitems [i4])
                if common/Mnumtrans > support:
                    print(i1, '|', i2, '|', i3 , '|', i4)
# Out:
# Boyhood | Gone Girl | Inside Out | The Imitation Game
# Big Hero 6 | Boyhood | Gone Girl | The Imitation Game
# Big Hero 6 | Gone Girl | Inside Out | The Imitation Game

# %% [markdown]
# ## Shopping dataset - association rules

# %% [markdown]
# ### Association rules with one item on the left-hand side

# %% [markdown]
# #### First compute frequent item-sets of one item, as candidate left-hand sides of assocation rules. Include the number of transactions the items occur in.

# %%
support = .5
frequentLHS = []
for i in Sitems:
    if len(Sitems[i])/Snumtrans > support:
        frequentLHS.append([i,len(Sitems[i])])
print(frequentLHS)
# Out:
# [['milk', 4], ['eggs', 3], ['juice', 3]]

# %% [markdown]
# #### Now find right-hand side items with sufficient confidence (see what's wrong and fix it)

# %%
# S -> i

confidence = .5
for lhs in frequentLHS:
  for i in Sitems:
    if i == lhs[0]:
      continue
    common = len(Sitems[lhs[0]] & Sitems[i])
    if common/lhs[1] > confidence: print(lhs[0], '->', i)
# Out:
# milk -> juice
# eggs -> milk
# juice -> milk
# juice -> cookies

# %% [markdown]
# ### Association rules with two items on the left-hand side

# %% [markdown]
# #### First compute frequent item-sets of two items, as candidate left-hand sides of assocation rules. Include the number of transactions the items occur in.

# %%
# S = [JUICE, MILK]
support = .5
frequentLHS = []
for i1 in Sitems:
    for i2 in Sitems:
        if i1 < i2:
            common = len(Sitems[i1] & Sitems[i2])
            if common/Snumtrans > support:
                frequentLHS.append([i1,i2,common])
print(frequentLHS)
# Out:
# [['juice', 'milk', 3]]

# %% [markdown]
# #### Now find right-hand side items with sufficient confidence

# %%
confidence = .5
for lhs in frequentLHS:
    for i in Sitems:
        if i not in lhs:
            common = len(Sitems[lhs[0]] & Sitems[lhs[1]] & Sitems[i])
            if common/lhs[2] > confidence:
                print(lhs[0], '|', lhs[1], '->', i)
# Out:
# juice | milk -> cookies

# %% [markdown]
# ## Shopping dataset - association rules with lift instead of confidence

# %% [markdown]
# ### Association rules with one item on the left-hand side

# %% [markdown]
# #### First compute frequent item-sets of one item, as candidate left-hand sides of assocation rules. Include the number of transactions the items occur in.

# %%
support = .5
frequentLHS = []
for i in Sitems:
    if len(Sitems[i])/Snumtrans > support:
        frequentLHS.append([i,len(Sitems[i])])
print(frequentLHS)
# Out:
# [['milk', 4], ['eggs', 3], ['juice', 3]]

# %% [markdown]
# #### Now find right-hand side items with sufficient lift

# %%
liftthresh = 1
for lhs in frequentLHS:
    for i in Sitems:
        if i not in lhs:
            common = len(Sitems[lhs[0]] & Sitems[i])
            lift = (common/lhs[1]) / (len(Sitems[i])/Snumtrans)
            if lift > liftthresh:
                print(lhs[0], '->', i, ' lift:', lift)
# Out:
# milk -> juice  lift: 1.25
# milk -> cookies  lift: 1.25
# juice -> milk  lift: 1.25
# juice -> cookies  lift: 1.6666666666666665

# %% [markdown]
# ### Association rules with two items on the left-hand side

# %% [markdown]
# #### First compute frequent item-sets of two items, as candidate left-hand sides of assocation rules. Include the number of transactions the items occur in.

# %%
support = .5
frequentLHS = []
for i1 in Sitems:
    for i2 in Sitems:
        if i1 < i2:
            common = len(Sitems[i1] & Sitems[i2])
            if common/Snumtrans > support:
                frequentLHS.append([i1,i2,common])
print(frequentLHS)
# Out:
# [['juice', 'milk', 3]]

# %% [markdown]
# #### Now find right-hand side items with sufficient lift

# %%
liftthresh = 1
for lhs in frequentLHS:
    for i in Sitems:
        if i not in lhs:
            common = len(Sitems[lhs[0]] & Sitems[lhs[1]] & Sitems[i])
            lift = (common/lhs[2]) / (len(Sitems[i])/Snumtrans)
            if lift > liftthresh:
                print(lhs[0], '|', lhs[1], '->', i, ' lift:', lift)
# Out:
# juice | milk -> cookies  lift: 1.6666666666666665

# %% [markdown]
# ### <font color = 'green'>**Your Turn - Movies dataset association rules**</font>

# %% [markdown]
# #### Mine for association rules in the Movies dataset with three items on the left-hand side. Find support and confidence thresholds (need not be the same) so the number of association rules is more than 10 but less than 20.

# %%
# Association rules with three items on the left-hand side
# Hint: Make sure to include the code from the seprate cells above that
#   together implement the two steps of association rule mining
support = 0.03
confidence = 0.6
frequentLHS = []
for i1 in Mitems:
    for i2 in Mitems:
        for i3 in Mitems:
            if i1 < i2 and i2 < i3:
                common = len(Mitems[i1] & Mitems[i2] & Mitems[i3])
                if common/Mnumtrans > support:
                  frequentLHS.append([i1,i2,i3,common])
# print(frequentLHS)

ruleCount = 0
for lhs in frequentLHS:
    for i in Mitems:
        if i not in lhs:
            common = len(Mitems[lhs[0]] & Mitems[lhs[1]] & Mitems[lhs[2]] & Mitems[i])
            if common/lhs[3] > confidence:
              ruleCount += 1
              print(lhs[0], '|', lhs[1], '|', lhs[2], '->', i)
# Out:
# Boyhood | Inside Out | The Imitation Game -> Big Hero 6
# Boyhood | Inside Out | The Imitation Game -> Gone Girl
# Boyhood | Gone Girl | Inside Out -> Big Hero 6
# Boyhood | Gone Girl | Inside Out -> The Imitation Game
# Boyhood | Fury | The Imitation Game -> Big Hero 6
# Boyhood | Fury | The Imitation Game -> Gone Girl
# Boyhood | Fury | Gone Girl -> Big Hero 6
# Boyhood | Fury | Gone Girl -> The Imitation Game
# Big Hero 6 | Boyhood | The Imitation Game -> Inside Out
# Big Hero 6 | Boyhood | The Imitation Game -> Gone Girl
# Big Hero 6 | Boyhood | Gone Girl -> The Imitation Game
# Big Hero 6 | Boyhood | Gone Girl -> Inside Out
# Big Hero 6 | Gone Girl | Inside Out -> The Imitation Game
# Big Hero 6 | Fury | The Imitation Game -> Boyhood
# Big Hero 6 | Fury | The Imitation Game -> Inside Out
# Big Hero 6 | Fury | The Imitation Game -> Gone Girl
# Big Hero 6 | Fury | Gone Girl -> Boyhood
# Big Hero 6 | Fury | Gone Girl -> The Imitation Game
# Big Hero 6 | Fury | Gone Girl -> Inside Out

# %%
print("support =", support, "confidence =", confidence)
print("LHS triples:", len(frequentLHS))
print("Rules:", ruleCount)
# Out:
# support = 0.03 confidence = 0.6
# LHS triples: 14
# Rules: 19

# %% [markdown]
# #### Mine for association rules in the Movies dataset with three items on the left-hand side. Find support and lift thresholds so the number of association rules is more than 10 but less than 20. Only consider lift thresholds > 1.

# %%
# Association rules with three items on the left-hand side
support = 0.038
liftthresh = 25
frequentLHS = []
for i1 in Mitems:
    for i2 in Mitems:
        for i3 in Mitems:
            if i1 < i2 and i2 < i3:
                common = len(Mitems[i1] & Mitems[i2] & Mitems[i3])
                if common/Mnumtrans > support:
                  frequentLHS.append([i1,i2,i3,common])
# print(frequentLHS)

ruleCount = 0
for lhs in frequentLHS:
    for i in Mitems:
        if i not in lhs:
            common = len(Mitems[lhs[0]] & Mitems[lhs[1]] & Mitems[lhs[2]] & Mitems[i])
            if common == 0:
                continue
            lift = (common/lhs[3]) / (len(Mitems[i])/Mnumtrans)
            if lift > liftthresh:
               ruleCount += 1
               print(lhs[0], '|', lhs[1], lhs[2], '->', i, ' lift:', lift)
# Out:
# Boyhood | Gone Girl Inside Out -> Blind  lift: 25.59259259259259
# Boyhood | Gone Girl Inside Out -> Catch Hell  lift: 25.59259259259259
# Boyhood | Gone Girl Inside Out -> Grandma  lift: 25.59259259259259
# Boyhood | Gone Girl Inside Out -> Flowers in the Attic  lift: 25.59259259259259
# Boyhood | Gone Girl Inside Out -> Whitey: United States of America v. James J. Bulger  lift: 25.59259259259259
# Boyhood | Gone Girl Inside Out -> The Wonders  lift: 25.59259259259259
# Boyhood | Gone Girl Inside Out -> Action Jackson  lift: 25.59259259259259
# Boyhood | Gone Girl Inside Out -> Breathe  lift: 25.59259259259259
# Boyhood | Gone Girl Inside Out -> Court  lift: 25.59259259259259
# Boyhood | Gone Girl Inside Out -> The Humbling  lift: 25.59259259259259
# Boyhood | Gone Girl Inside Out -> I'll See You in My Dreams  lift: 25.59259259259259
# Boyhood | Gone Girl Inside Out -> Outcast  lift: 25.59259259259259
# Boyhood | Gone Girl Inside Out -> Time Out of Mind  lift: 25.59259259259259
# Boyhood | Gone Girl Inside Out -> Far from Men  lift: 25.59259259259259

# %%
print("support =", support, "liftthresh =", liftthresh)
print("Rules:", ruleCount)
# Out:
# support = 0.038 liftthresh = 25
# Rules: 14
